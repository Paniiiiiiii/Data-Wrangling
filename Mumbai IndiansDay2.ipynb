# %%
import sys

# %%
import numpy as np
import pandas as pd
import tweepy
import matplotlib.pyplot as plt
import pymongo
import ipywidgets as wgt
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
import re
from datetime import datetime

# %matplotlib inline

# %%
api_key = "pCRLPdf2lkjpRX9Uczpt2gVBb" 
api_secret = "G1Wv7sTLMYF3cr5LbL8S9uj2g2LFrdWp8X8t7Ft3sIpW0kbqgD" 
access_token = "100875722-7m5vhOzpw2LYrB7P8ISnTqtGYMMvVTqwx3X4EyJY" 
access_token_secret = "uPEymGiszhiJEVWD4Alo1pzMUJx1ymo3Fd4HWyRPRBN3r" 

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
col = pymongo.MongoClient()["DataWranglingDay2"]["Mumbai Indians"]
col.count()
# Out:
# <ipython-input-33-0b44628bab67>:11: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   col.count()
# 62

# %%
class MyStreamListener(tweepy.StreamListener):
    
    counter = 0
    
    def __init__(self, max_tweets=3000, *args, **kwargs):
        self.max_tweets = max_tweets
        self.counter = 0
        super().__init__(*args, **kwargs)
    
    def on_connect(self):
        self.counter = 0
        self.start_time = datetime.now()
    
    def on_status(self, status):
        
        self.counter += 1
        
        
        col.insert_one(status._json)
        
        
        if self.counter % 1 == 0:
            value = int(100.00 * self.counter / self.max_tweets)
            mining_time = datetime.now() - self.start_time
            progress_bar.value = value
            html_value = """<span class="label label-primary">Tweets/Sec: %.1f</span>""" % (self.counter / max([1,mining_time.seconds]))
            html_value += """ <span class="label label-success">Progress: %.1f%%</span>""" % (self.counter / self.max_tweets * 100.0)
            html_value += """ <span class="label label-info">ETA: %.1f Sec</span>""" % ((self.max_tweets - self.counter) / (self.counter / max([1,mining_time.seconds])))
            wgt_status.value = html_value
           
            if self.counter >= self.max_tweets:
                myStream.disconnect()
                print("Finished")
                print("Total Mining Time: %s" % (mining_time))
                print("Tweets/Sec: %.1f" % (self.max_tweets / mining_time.seconds))
                progress_bar.value = 0
                
    
myStreamListener = MyStreamListener(max_tweets=5000)
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
keywords = ["Mumbai Indians",""
           ]


progress_bar = wgt.IntProgress(value=0)
display(progress_bar)
wgt_status = wgt.HTML(value="""<span class="label label-primary">Tweets/Sec: 0.0</span>""")
display(wgt_status)


for error_counter in range(20):
    try:
        myStream.filter(track=keywords)
        print("Tweets collected: %s" % myStream.listener.counter)
        print("Total tweets in collection: %s" % col.count())
        break
    except:
        print("ERROR# %s" % (error_counter + 1))
# Out:
# IntProgress(value=0)
# HTML(value='<span class="label label-primary">Tweets/Sec: 0.0</span>')
# Tweets collected: 0
# Total tweets in collection: 62
# <ipython-input-34-15a302562efb>:55: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print("Total tweets in collection: %s" % col.count())

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5f9829b0a1a065969349ea86'),
#  'created_at': 'Tue Oct 27 14:07:37 +0000 2020',
#  'id': 1321091182236176386,
#  'id_str': '1321091182236176386',
#  'text': 'RT @hp_mode2: Chris Lynn in Mumbai Indians : https://t.co/RQu16ZwhqG',
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1159659452464631808,
#   'id_str': '1159659452464631808',
#   'name': 'Sumit jadhav',
#   'screen_name': 'Ekdum_Jhakaasss',
#   'location': 'Mumbai, India',
#   'url': None,
#   'description': 'Dhoni, Dhoni, Dhoni..😍❤️🔥',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 312,
#   'friends_count': 182,
#   'listed_count': 0,
#   'favourites_count': 10275,
#   'statuses_count': 9816,
#   'created_at': 'Fri Aug 09 02:55:33 +0000 2019',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318727970362544130/8VmN4WPB_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318727970362544130/8VmN4WPB_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1159659452464631808/1569208299',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Tue Oct 27 13:05:48 +0000 2020',
#   'id': 1321075626237779968,
#   'id_str': '1321075626237779968',
#   'text': 'Chris Lynn in Mumbai Indians : https://t.co/RQu16ZwhqG',
#   'display_text_range': [0, 30],
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1182328019643330561,
#    'id_str': '1182328019643330561',
#    'name': 'HUNTSMAN🐇',
#    'screen_name': 'hp_mode2',
#    'location': 'Mumbai Indians',
#    'url': 'https://instagram.com/hp_mode?igshid=avcqyz723lql',
#    'description': "lame tweets | lil bit funny/hypocrite | memes | Follow me I'll make you laugh :)",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 5084,
#    'friends_count': 1036,
#    'listed_count': 0,
#    'favourites_count': 108963,
#    'statuses_count': 60472,
#    'created_at': 'Thu Oct 10 16:12:53 +0000 2019',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1302602482854424576/i1L46P1P_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1302602482854424576/i1L46P1P_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1182328019643330561/1601829133',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 7,
#   'retweet_count': 37,
#   'favorite_count': 89,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': [],
#    'media': [{'id': 1321075601613049856,
#      'id_str': '1321075601613049856',
#      'indices': [31, 54],
#      'media_url': 'http://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#      'url': 'https://t.co/RQu16ZwhqG',
#      'display_url': 'pic.twitter.com/RQu16ZwhqG',
#      'expanded_url': 'https://twitter.com/hp_mode2/status/1321075626237779968/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 392, 'resize': 'fit'},
#       'large': {'w': 1873, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 692, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1321075601613049856,
#      'id_str': '1321075601613049856',
#      'indices': [31, 54],
#      'media_url': 'http://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#      'url': 'https://t.co/RQu16ZwhqG',
#      'display_url': 'pic.twitter.com/RQu16ZwhqG',
#      'expanded_url': 'https://twitter.com/hp_mode2/status/1321075626237779968/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'small': {'w': 680, 'h': 392, 'resize': 'fit'},
#       'large': {'w': 1873, 'h': 1080, 'resize': 'fit'},
#       'medium': {'w': 1200, 'h': 692, 'resize': 'fit'}}}]},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'et'},
#  'is_quote_status': False,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [],
#   'user_mentions': [{'screen_name': 'hp_mode2',
#     'name': 'HUNTSMAN🐇',
#     'id': 1182328019643330561,
#     'id_str': '1182328019643330561',
#     'indices': [3, 12]}],
#   'symbols': [],
#   'media': [{'id': 1321075601613049856,
#     'id_str': '1321075601613049856',
#     'indices': [45, 68],
#     'media_url': 'http://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#     'url': 'https://t.co/RQu16ZwhqG',
#     'display_url': 'pic.twitter.com/RQu16ZwhqG',
#     'expanded_url': 'https://twitter.com/hp_mode2/status/1321075626237779968/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 392, 'resize': 'fit'},
#      'large': {'w': 1873, 'h': 1080, 'resize': 'fit'},
#      'medium': {'w': 1200, 'h': 692, 'resize': 'fit'}},
#     'source_status_id': 1321075626237779968,
#     'source_status_id_str': '1321075626237779968',
#     'source_user_id': 1182328019643330561,
#     'source_user_id_str': '1182328019643330561'}]},
#  'extended_entities': {'media': [{'id': 1321075601613049856,
#     'id_str': '1321075601613049856',
#     'indices': [45, 68],
#     'media_url': 'http://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#     'media_url_https': 'https://pbs.twimg.com/media/ElVnQqOU0AAPRZ0.jpg',
#     'url': 'https://t.co/RQu16ZwhqG',
#     'display_url': 'pic.twitter.com/RQu16ZwhqG',
#     'expanded_url': 'https://twitter.com/hp_mode2/status/1321075626237779968/photo/1',
#     'type': 'photo',
#     'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#      'small': {'w': 680, 'h': 392, 'resize': 'fit'},
#      'large': {'w': 1873, 'h': 1080, 'resize': 'fit'},
#      'medium': {'w': 1200, 'h': 692, 'resize': 'fit'}},
#     'source_status_id': 1321075626237779968,
#     'source_status_id_str': '1321075626237779968',
#     'source_user_id': 1182328019643330561,
#     'source_user_id_str': '1182328019643330561'}]},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'et',
#  'timestamp_ms': '1603807657189'}

# %%
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
            "user": "@%s" % item["user"]["screen_name"],
            "source": item["source"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset = pd.DataFrame(dataset)

dataset
# Out:
#                         created_at  \
# 0   Tue Oct 27 14:07:37 +0000 2020
# 1   Tue Oct 27 14:08:09 +0000 2020
# 2   Tue Oct 27 14:09:49 +0000 2020
# 3   Tue Oct 27 14:10:00 +0000 2020
# 4   Tue Oct 27 14:10:51 +0000 2020
# ..                             ...
# 57  Tue Oct 27 14:55:16 +0000 2020
# 58  Tue Oct 27 14:55:18 +0000 2020
# 59  Tue Oct 27 14:55:34 +0000 2020
# 60  Tue Oct 27 14:56:14 +0000 2020
# 61  Tue Oct 27 14:56:46 +0000 2020
#
#                                                  text              user  \
# 0   RT @hp_mode2: Chris Lynn in Mumbai Indians : h...  @Ekdum_Jhakaasss
# 1   RT @TheHinduSports: Royal Challengers Bangalor...      @Rajagupta22
# 2   RT @Mahesh_Fan_Girl: Quotes 😂😂🙌🙌\n\n#SarkaruVa...     @MaharshiVenu
# 3   RT @hp_mode2: Chris Lynn in Mumbai Indians : h...       @memebandhu
# 4   RT @cricbuzz: 8:41pm IST -- BCCI announce the ...           @Impk54
# ..                                                ...               ...
# 57  Sunil Gavaskar said that we are talking about ...      @midhul_cric
# 58  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...     @sandyvenkate
# 59  RT @parmarsap: @upma23 @devikasmittal J&amp;K ...  @Kashish04305073
# 60  @SunRisers next year mumbai indians team nundi...        @Vadagaali
# 61  RT @hp_mode2: Chris Lynn in Mumbai Indians : h...  @be_like_gaurang
#
#                                                source lang
# 0   <a href="http://twitter.com/download/android" ...   et
# 1   <a href="http://twitter.com/download/android" ...   en
# 2   <a href="http://twitter.com/download/android" ...   en
# 3   <a href="https://mobile.twitter.com" rel="nofo...   et
# 4   <a href="http://twitter.com/download/android" ...   en
# ..                                                ...  ...
# 57  <a href="https://mobile.twitter.com" rel="nofo...   en
# 58  <a href="http://twitter.com/download/android" ...   en
# 59  <a href="https://mobile.twitter.com" rel="nofo...   en
# 60  <a href="http://twitter.com/download/iphone" r...   in
# 61  <a href="http://twitter.com/download/android" ...   et
#
# [62 rows x 5 columns]

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(dataset.text)

word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#            word  count
# 0            rt     44
# 1        mumbai     35
# 2       indians     33
# 3            in     25
# 4           the     24
# 5         https     19
# 6            co     19
# 7            is     18
# 8          bcci     16
# 9            to     15
# 10          and     15
# 11        rohit     15
# 12           on     13
# 13          not     12
# 14       indian     12
# 15       sharma     12
# 16          for     10
# 17         tour      9
# 18       squads      9
# 19         team      9
# 20      fitness      8
# 21      grounds      8
# 22     hp_mode2      8
# 23           it      8
# 24        there      8
# 25        chris      8
# 26          ist      8
# 27    australia      8
# 28     cricbuzz      8
# 29     announce      8
# 30          36p      8
# 31           10      8
# 32         41pm      8
# 33        leave      8
# 34          out      8
# 35         lynn      8
# 36   rqu16zwhqg      8
# 37        royal      6
# 38  challengers      6
# 39      session      6
# 40    bangalore      6
# 41           of      6
# 42        their      5
# 43        about      5
# 44         this      5
# 45         from      5
# 46          any      5
# 47        which      5
# 48   itgdsports      4
# 49      injured      4

# %%
def get_source_name(x):
    value = re.findall(pattern="<[^>]+>([^<]+)</a>", string=x)
    if len(value) > 0:
        return value[0]
    else:
        return ""
dataset.source_name = dataset.source.apply(get_source_name)

source_counts = dataset.source_name.value_counts().sort_values()[-10:]

bottom = [index for index, item in enumerate(source_counts.index)]
plt.barh(bottom, width=source_counts, color="blue", linewidth=0)

y_labels = ["%s %.1f%%" % (item, 100.0*source_counts[item]/len(dataset)) for index,item in enumerate(source_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)

source_counts
# Out:
# <ipython-input-38-a8481ec67a37>:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.source_name = dataset.source.apply(get_source_name)
# WordPress.com           1
# IFTTT                   3
# Twitter for iPhone      5
# Twitter Web App         8
# Twitter for Android    45
# Name: source, dtype: int64

# %%
lang_counts = dataset.lang.value_counts().sort_values()[-10:]
bottom = [index for index, item in enumerate(lang_counts.index)]
plt.barh(bottom, width=lang_counts, color="green", linewidth=0)
y_labels = ["%s %.1f%%" % (item, 100.0*lang_counts[item]/len(dataset)) for index,item in enumerate(lang_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)
lang_counts
# Out:
# und     1
# ta      1
# fr      2
# hi      4
# in      5
# et      8
# en     41
# Name: lang, dtype: int64

# %%
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
from  textblob import TextBlob

# %%
dataset1 = [{"id": item["id"],
            "text": item["text"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset1 = pd.DataFrame(dataset1)

is_dataset1=dataset1.lang=="en"
dataset1=dataset1[is_dataset1]
dataset1
# Out:
#                      id                                               text  \
# 1   1321091319251554304  RT @TheHinduSports: Royal Challengers Bangalor...
# 2   1321091737641721862  RT @Mahesh_Fan_Girl: Quotes 😂😂🙌🙌\n\n#SarkaruVa...
# 4   1321091995910262784  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 5   1321092018978869249  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 6   1321092176831516672  RT @Cheeku218: This is Old Video which Mumbai ...
# 7   1321092184209264648  RT @Pranjal_one8: It's Not BCCI, Fault is on M...
# 9   1321092525092933647  RT @Pranjal_one8: It's Not BCCI, Fault is on M...
# 10  1321092621926862852  RT @CricketNDTV: #MumbaiIndians and #RoyalChal...
# 11  1321092843834875905  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 13  1321093392684752896  @rungta_ridhima @Ctrlmemes_ Ah well! U only wa...
# 15  1321094707460612097  RT @NaviKRStan: @LiveLawIndia @KanganaTeam She...
# 16  1321094749588172800  RT @Pranjal_one8: It's Not BCCI, Fault is on M...
# 17  1321095592689438723  Mumbai Indians vs Royal Challengers Bangalore,...
# 19  1321095815922917376  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 23  1321096718709149703  RT @ITGDsports: "Rohit is not there in any tea...
# 25  1321097630806614017  Mumbai Indians vs Royal Challengers Bangalore,...
# 26  1321097768081866752  I'm getting 2013-14 liverpool vibes from Mumba...
# 29  1321098178301603841  RT @ITGDsports: "Rohit is not there in any tea...
# 31  1321098381427576834  RT @AvengerReturns: They clearly mentioned dur...
# 32  1321098425841008645  RT @cricketwallah: If Rohit Sharma not fit to ...
# 34  1321098856352882688  RT @omkarmali45: #RohithSharma #IPL2020\n@ImRo...
# 35  1321099276433248257  Hello Expert, \nDo you think Delhi team is str...
# 36  1321099353537347585  Thalaivan in Kapil Sharma show whilst we were ...
# 37  1321099773760335879  Mumbai Indians v Royal Challengers Bangalore\n...
# 38  1321099871550500865     Made my Mumbai - Mangalore life so comfortable
# 39  1321099909995507713  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 40  1321100309112844289  RT @Pranjal_one8: It's Not BCCI, Fault is on M...
# 41  1321100711417925632  RT @double_century: Hence Proved 🤭 https://t.c...
# 44  1321100919841255424  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 45  1321100955652272128  RT @Cheeku218: This is Old Video which Mumbai ...
# 48  1321101256224612353  RT @AftabNizami5: @AljawazatKSA Saudi airlines...
# 49  1321101883688140801  RT @ITGDsports: "Rohit is not there in any tea...
# 50  1321101953452052481  RT @AvengerReturns: They clearly mentioned dur...
# 51  1321102141189058560  RT @ITGDsports: "Rohit is not there in any tea...
# 52  1321102215407259655  RT @BeinggRana45: "During a training session. ...
# 53  1321102355979382786  RT @double_century: Hence Proved 🤭 https://t.c...
# 54  1321102457716396034  RT @double_century: Hence Proved 🤭 https://t.c...
# 55  1321102620405026821  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 57  1321103176427139075  Sunil Gavaskar said that we are talking about ...
# 58  1321103184031432704  RT @cricbuzz: 8:41pm IST -- BCCI announce the ...
# 59  1321103252239179776  RT @parmarsap: @upma23 @devikasmittal J&amp;K ...
#
#    lang
# 1    en
# 2    en
# 4    en
# 5    en
# 6    en
# 7    en
# 9    en
# 10   en
# 11   en
# 13   en
# 15   en
# 16   en
# 17   en
# 19   en
# 23   en
# 25   en
# 26   en
# 29   en
# 31   en
# 32   en
# 34   en
# 35   en
# 36   en
# 37   en
# 38   en
# 39   en
# 40   en
# 41   en
# 44   en
# 45   en
# 48   en
# 49   en
# 50   en
# 51   en
# 52   en
# 53   en
# 54   en
# 55   en
# 57   en
# 58   en
# 59   en

# %%
tweettext=dataset1['text']
wordlist=pd.DataFrame();

polarity=[]
subj=[]

for t in tweettext:
    tx= TextBlob(t)
    polarity.append(tx.sentiment.polarity)
    subj.append(tx.sentiment.subjectivity)

poltweet= pd.DataFrame({'polarity':polarity,'subjectivity':subj})
poltweet.polarity.plot(title='Polarity')
plt.show()

# %%
poltweet.subjectivity.plot(title='Subjectivity')
plt.show()

# %%
import statistics
statistics.mean(poltweet.polarity)
# Out:
# 0.019918699186991868

# %%
import statistics
statistics.mean(poltweet.subjectivity)
# Out:
# 0.18841463414634146

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

def wc(data,bgcolor,title):
    plt.figure(figsize = (100,100))
    wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
top_N = 100


a = dataset1['text'].str.lower().str.cat(sep=' ')


b = re.sub('[^A-Za-z]+', ' ', a)
nltk.download('stopwords')
nltk.download('punkt')
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import seaborn as sns
 
without_single_chr = [word for word in filtered_sentence if len(word) > 2]


cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        


word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Common Words' )

# %%
from textblob import TextBlob

bloblist_desc = list()

twit=dataset1['text'].astype(str)
for row in twit:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    twit_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
    
def f(twit_polarity_desc):
    if twit_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif twit_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

twit_polarity_desc['Sentiment_Type'] = twit_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")

# %%
import collections, numpy as np
a=twit_polarity_desc.Sentiment_Type
neut=np.count_nonzero(a == 'Neutral')
pos=np.count_nonzero(a == 'Positive')
neg=np.count_nonzero(a == 'Negative')
popularity='{0:.2f}'.format((((neut*0.5)+(pos)+(neg*0))/(neut+pos+neg))*100)
popularity
# Out:
# '51.22'
