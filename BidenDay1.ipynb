# %%
import sys

# %%
import numpy as np
import pandas as pd
import tweepy
import matplotlib.pyplot as plt
import pymongo
import ipywidgets as wgt
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
import re
from datetime import datetime

# %matplotlib inline

# %%
api_key = "pCRLPdf2lkjpRX9Uczpt2gVBb" 
api_secret = "G1Wv7sTLMYF3cr5LbL8S9uj2g2LFrdWp8X8t7Ft3sIpW0kbqgD" 
access_token = "100875722-7m5vhOzpw2LYrB7P8ISnTqtGYMMvVTqwx3X4EyJY" 
access_token_secret = "uPEymGiszhiJEVWD4Alo1pzMUJx1ymo3Fd4HWyRPRBN3r" 

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
col = pymongo.MongoClient()["DataWranglingDay1"]["Biden"]
col.count()
# Out:
# <ipython-input-25-c20fc9df314c>:11: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   col.count()
# 10000

# %%
class MyStreamListener(tweepy.StreamListener):
    
    counter = 0
    
    def __init__(self, max_tweets=3000, *args, **kwargs):
        self.max_tweets = max_tweets
        self.counter = 0
        super().__init__(*args, **kwargs)
    
    def on_connect(self):
        self.counter = 0
        self.start_time = datetime.now()
    
    def on_status(self, status):
        
        self.counter += 1
        
        
        col.insert_one(status._json)
        
        
        if self.counter % 1 == 0:
            value = int(100.00 * self.counter / self.max_tweets)
            mining_time = datetime.now() - self.start_time
            progress_bar.value = value
            html_value = """<span class="label label-primary">Tweets/Sec: %.1f</span>""" % (self.counter / max([1,mining_time.seconds]))
            html_value += """ <span class="label label-success">Progress: %.1f%%</span>""" % (self.counter / self.max_tweets * 100.0)
            html_value += """ <span class="label label-info">ETA: %.1f Sec</span>""" % ((self.max_tweets - self.counter) / (self.counter / max([1,mining_time.seconds])))
            wgt_status.value = html_value
           
            if self.counter >= self.max_tweets:
                myStream.disconnect()
                print("Finished")
                print("Total Mining Time: %s" % (mining_time))
                print("Tweets/Sec: %.1f" % (self.max_tweets / mining_time.seconds))
                progress_bar.value = 0
                
    
myStreamListener = MyStreamListener(max_tweets=5000)
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
keywords = ["Biden",""
           ]


progress_bar = wgt.IntProgress(value=0)
display(progress_bar)
wgt_status = wgt.HTML(value="""<span class="label label-primary">Tweets/Sec: 0.0</span>""")
display(wgt_status)


for error_counter in range(20):
    try:
        myStream.filter(track=keywords)
        print("Tweets collected: %s" % myStream.listener.counter)
        print("Total tweets in collection: %s" % col.count())
        break
    except:
        print("ERROR# %s" % (error_counter + 1))
# Out:
# IntProgress(value=0)
# HTML(value='<span class="label label-primary">Tweets/Sec: 0.0</span>')
# Tweets collected: 0
# Total tweets in collection: 10000
# <ipython-input-26-2b9117ab4939>:55: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print("Total tweets in collection: %s" % col.count())

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5f964f5c4179f33014da6a40'),
#  'created_at': 'Mon Oct 26 04:23:50 +0000 2020',
#  'id': 1320581883416162305,
#  'id_str': '1320581883416162305',
#  'text': 'RT @LaurynnWilliams: KEEP VOTING! JUST BECAUSE BIDEN IS UP DOES NOT MEAN YOU STOP VOTING! KEEP IT UP!!!!! https://t.co/hzuGI6i6W9',
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': False,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 818650679053090816,
#   'id_str': '818650679053090816',
#   'name': 'chicacloudy',
#   'screen_name': 'ortiz_asf',
#   'location': None,
#   'url': None,
#   'description': 'Let life surprise you💫',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 314,
#   'friends_count': 283,
#   'listed_count': 0,
#   'favourites_count': 19145,
#   'statuses_count': 8796,
#   'created_at': 'Tue Jan 10 02:48:26 +0000 2017',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': False,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_link_color': 'F58EA8',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1318905155065176065/P_66zVVv_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1318905155065176065/P_66zVVv_normal.jpg',
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/818650679053090816/1603583646',
#   'default_profile': False,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'retweeted_status': {'created_at': 'Thu Oct 22 20:46:26 +0000 2020',
#   'id': 1319379611764072449,
#   'id_str': '1319379611764072449',
#   'text': 'KEEP VOTING! JUST BECAUSE BIDEN IS UP DOES NOT MEAN YOU STOP VOTING! KEEP IT UP!!!!! https://t.co/hzuGI6i6W9',
#   'display_text_range': [0, 84],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1167899186,
#    'id_str': '1167899186',
#    'name': 'Chardonnay🥂',
#    'screen_name': 'LaurynnWilliams',
#    'location': None,
#    'url': 'https://www.change.org/p/international-criminal-court-petition-for-president-buhari-to-be-charged-before-the-icc-for-crimes-against-humanity',
#    'description': 'Tall Glass of Lightskin',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2561,
#    'friends_count': 557,
#    'listed_count': 2,
#    'favourites_count': 91432,
#    'statuses_count': 55927,
#    'created_at': 'Mon Feb 11 05:12:05 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1320012777688305670/HFmbOiBF_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1320012777688305670/HFmbOiBF_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1167899186/1603418711',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'quoted_status_id': 1319120391344951305,
#   'quoted_status_id_str': '1319120391344951305',
#   'quoted_status': {'created_at': 'Thu Oct 22 03:36:24 +0000 2020',
#    'id': 1319120391344951305,
#    'id_str': '1319120391344951305',
#    'text': "Trump loses lead in Texas, where Democrats haven't won since 1976 https://t.co/CUavp6BN5g",
#    'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>',
#    'truncated': False,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2884771,
#     'id_str': '2884771',
#     'name': 'Newsweek',
#     'screen_name': 'Newsweek',
#     'location': 'New York, NY',
#     'url': 'http://www.newsweek.com',
#     'description': 'The freedom to disagree. Our staff likes to tweet: https://twitter.com/Newsweek/lists/newsweek-editorial',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 3451131,
#     'friends_count': 521,
#     'listed_count': 36647,
#     'favourites_count': 2653,
#     'statuses_count': 250186,
#     'created_at': 'Thu Mar 29 19:51:11 +0000 2007',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': None,
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'EE2A26',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': True,
#     'profile_link_color': '990000',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'F2F2F2',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/741603495929905152/di0NxkFa_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741603495929905152/di0NxkFa_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2884771/1554409697',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'quote_count': 1150,
#    'reply_count': 1449,
#    'retweet_count': 1480,
#    'favorite_count': 6722,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/CUavp6BN5g',
#       'expanded_url': 'https://www.newsweek.com/trump-loses-lead-texas-where-democrats-havent-won-since-1976-1541117?utm_term=Autofeed&utm_medium=Social&utm_source=Twitter#Echobox=1603314532',
#       'display_url': 'newsweek.com/trump-loses-le…',
#       'indices': [66, 89]}],
#     'user_mentions': [],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/hzuGI6i6W9',
#    'expanded': 'https://twitter.com/Newsweek/status/1319120391344951305',
#    'display': 'twitter.com/Newsweek/statu…'},
#   'is_quote_status': True,
#   'quote_count': 321,
#   'reply_count': 31,
#   'retweet_count': 31805,
#   'favorite_count': 65254,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/hzuGI6i6W9',
#      'expanded_url': 'https://twitter.com/Newsweek/status/1319120391344951305',
#      'display_url': 'twitter.com/Newsweek/statu…',
#      'indices': [85, 108]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_id': 1319120391344951305,
#  'quoted_status_id_str': '1319120391344951305',
#  'quoted_status': {'created_at': 'Thu Oct 22 03:36:24 +0000 2020',
#   'id': 1319120391344951305,
#   'id_str': '1319120391344951305',
#   'text': "Trump loses lead in Texas, where Democrats haven't won since 1976 https://t.co/CUavp6BN5g",
#   'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2884771,
#    'id_str': '2884771',
#    'name': 'Newsweek',
#    'screen_name': 'Newsweek',
#    'location': 'New York, NY',
#    'url': 'http://www.newsweek.com',
#    'description': 'The freedom to disagree. Our staff likes to tweet: https://twitter.com/Newsweek/lists/newsweek-editorial',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': True,
#    'followers_count': 3451131,
#    'friends_count': 521,
#    'listed_count': 36647,
#    'favourites_count': 2653,
#    'statuses_count': 250186,
#    'created_at': 'Thu Mar 29 19:51:11 +0000 2007',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': None,
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'EE2A26',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_link_color': '990000',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F2F2F2',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/741603495929905152/di0NxkFa_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/741603495929905152/di0NxkFa_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2884771/1554409697',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 1150,
#   'reply_count': 1449,
#   'retweet_count': 1480,
#   'favorite_count': 6722,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/CUavp6BN5g',
#      'expanded_url': 'https://www.newsweek.com/trump-loses-lead-texas-where-democrats-havent-won-since-1976-1541117?utm_term=Autofeed&utm_medium=Social&utm_source=Twitter#Echobox=1603314532',
#      'display_url': 'newsweek.com/trump-loses-le…',
#      'indices': [66, 89]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en'},
#  'quoted_status_permalink': {'url': 'https://t.co/hzuGI6i6W9',
#   'expanded': 'https://twitter.com/Newsweek/status/1319120391344951305',
#   'display': 'twitter.com/Newsweek/statu…'},
#  'is_quote_status': True,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/hzuGI6i6W9',
#     'expanded_url': 'https://twitter.com/Newsweek/status/1319120391344951305',
#     'display_url': 'twitter.com/Newsweek/statu…',
#     'indices': [106, 129]}],
#   'user_mentions': [{'screen_name': 'LaurynnWilliams',
#     'name': 'Chardonnay🥂',
#     'id': 1167899186,
#     'id_str': '1167899186',
#     'indices': [3, 19]}],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': True,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1603686230888'}

# %%
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
            "user": "@%s" % item["user"]["screen_name"],
            "source": item["source"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset = pd.DataFrame(dataset)

dataset
# Out:
#                           created_at  \
# 0     Mon Oct 26 04:23:50 +0000 2020
# 1     Mon Oct 26 04:23:50 +0000 2020
# 2     Mon Oct 26 04:23:50 +0000 2020
# 3     Mon Oct 26 04:23:50 +0000 2020
# 4     Mon Oct 26 04:23:50 +0000 2020
# ...                              ...
# 9995  Mon Oct 26 04:27:45 +0000 2020
# 9996  Mon Oct 26 04:27:45 +0000 2020
# 9997  Mon Oct 26 04:27:45 +0000 2020
# 9998  Mon Oct 26 04:27:45 +0000 2020
# 9999  Mon Oct 26 04:27:45 +0000 2020
#
#                                                    text              user  \
# 0     RT @LaurynnWilliams: KEEP VOTING! JUST BECAUSE...        @ortiz_asf
# 1     RT @VivaLaMaquis: Can some PLEASE tell this ma...     @FloridaBiden
# 2     RT @AmoneyResists: .@kayleighmcenany handing L...      @ScottKGarbo
# 3     RT @TheRightMelissa: @50cent President Trump h...       @bassil_sam
# 4     RT @wsteaks: New Trump campaign ad calls Joe B...          @SCAM518
# ...                                                 ...               ...
# 9995  RT @TreyJoens: This is sad...but this is who h...   @AllenMeallen20
# 9996  RT @DevinNunes: Biden corruption claims all bu...        @millersis
# 9997  RT @SteveGuest: Joe Biden confuses President T...       @SArchibald
# 9998  RT @dbongino: Does “BIG GUY” Joe Biden’s cut f...  @RobertMcGowen17
# 9999  RT @funder: BREAKING: Trump Chief Mark Meadows...      @sandram3737
#
#                                                  source lang
# 0     <a href="https://mobile.twitter.com" rel="nofo...   en
# 1     <a href="https://mobile.twitter.com" rel="nofo...   en
# 2     <a href="http://twitter.com/#!/download/ipad" ...   en
# 3     <a href="http://twitter.com/download/iphone" r...   en
# 4     <a href="http://twitter.com/download/iphone" r...   en
# ...                                                 ...  ...
# 9995  <a href="http://twitter.com/download/android" ...   en
# 9996  <a href="http://twitter.com/download/android" ...   en
# 9997  <a href="http://twitter.com/download/android" ...   en
# 9998  <a href="http://twitter.com/download/iphone" r...   en
# 9999  <a href="https://mobile.twitter.com" rel="nofo...   en
#
# [10000 rows x 5 columns]

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(dataset.text)

word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt   7884
# 1               the   5929
# 2             trump   4234
# 3             biden   4004
# 4                to   3273
# 5                is   3018
# 6             https   2735
# 7               and   2607
# 8                co   2509
# 9                of   2491
# 10               in   1829
# 11              for   1828
# 12             this   1698
# 13               he   1652
# 14              joe   1583
# 15             that   1485
# 16               it   1382
# 17               on   1174
# 18              you   1021
# 19        president    996
# 20              are    973
# 21             with    889
# 22             they    885
# 23              was    879
# 24               if    721
# 25              not    698
# 26           hunter    689
# 27              all    674
# 28               we    658
# 29              his    654
# 30               be    633
# 31              has    609
# 32             have    585
# 33            about    584
# 34             just    572
# 35               no    534
# 36              who    533
# 37             vote    530
# 38             from    525
# 39             what    524
# 40             more    516
# 41  realdonaldtrump    508
# 42          minutes    487
# 43              how    486
# 44             will    467
# 45              can    448
# 46               up    448
# 47              out    442
# 48           donald    436
# 49               as    431

# %%
def get_source_name(x):
    value = re.findall(pattern="<[^>]+>([^<]+)</a>", string=x)
    if len(value) > 0:
        return value[0]
    else:
        return ""
dataset.source_name = dataset.source.apply(get_source_name)

source_counts = dataset.source_name.value_counts().sort_values()[-10:]

bottom = [index for index, item in enumerate(source_counts.index)]
plt.barh(bottom, width=source_counts, color="blue", linewidth=0)

y_labels = ["%s %.1f%%" % (item, 100.0*source_counts[item]/len(dataset)) for index,item in enumerate(source_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)

source_counts
# Out:
# <ipython-input-30-a8481ec67a37>:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.source_name = dataset.source.apply(get_source_name)
# TwitPanePlus                  4
# WordPress.com                 5
# TweetCaster for Android       5
# Twitterrific for iOS         11
# Tweetbot for iΟS             16
# TweetDeck                    25
# Twitter for iPad            616
# Twitter Web App            2221
# Twitter for Android        2697
# Twitter for iPhone         4341
# Name: source, dtype: int64

# %%
lang_counts = dataset.lang.value_counts().sort_values()[-10:]
bottom = [index for index, item in enumerate(lang_counts.index)]
plt.barh(bottom, width=lang_counts, color="green", linewidth=0)
y_labels = ["%s %.1f%%" % (item, 100.0*lang_counts[item]/len(dataset)) for index,item in enumerate(lang_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)
lang_counts
# Out:
# sv        7
# de        8
# tl       11
# ja       20
# zh       27
# pt       35
# fr       36
# es       73
# und     374
# en     9367
# Name: lang, dtype: int64

# %%
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
from  textblob import TextBlob

# %%
dataset1 = [{"id": item["id"],
            "text": item["text"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset1 = pd.DataFrame(dataset1)

is_dataset1=dataset1.lang=="en"
dataset1=dataset1[is_dataset1]
dataset1
# Out:
#                        id                                               text  \
# 0     1320581883416162305  RT @LaurynnWilliams: KEEP VOTING! JUST BECAUSE...
# 1     1320581883525292032  RT @VivaLaMaquis: Can some PLEASE tell this ma...
# 2     1320581883521048576  RT @AmoneyResists: .@kayleighmcenany handing L...
# 3     1320581883617447936  RT @TheRightMelissa: @50cent President Trump h...
# 4     1320581883646926848  RT @wsteaks: New Trump campaign ad calls Joe B...
# ...                   ...                                                ...
# 9995  1320582867957751813  RT @TreyJoens: This is sad...but this is who h...
# 9996  1320582868209381381  RT @DevinNunes: Biden corruption claims all bu...
# 9997  1320582868238659586  RT @SteveGuest: Joe Biden confuses President T...
# 9998  1320582868238782464  RT @dbongino: Does “BIG GUY” Joe Biden’s cut f...
# 9999  1320582868297535488  RT @funder: BREAKING: Trump Chief Mark Meadows...
#
#      lang
# 0      en
# 1      en
# 2      en
# 3      en
# 4      en
# ...   ...
# 9995   en
# 9996   en
# 9997   en
# 9998   en
# 9999   en
#
# [9367 rows x 3 columns]

# %%
tweettext=dataset1['text']
wordlist=pd.DataFrame();

polarity=[]
subj=[]

for t in tweettext:
    tx= TextBlob(t)
    polarity.append(tx.sentiment.polarity)
    subj.append(tx.sentiment.subjectivity)

poltweet= pd.DataFrame({'polarity':polarity,'subjectivity':subj})
poltweet.polarity.plot(title='Polarity')
plt.show()

# %%
poltweet.subjectivity.plot(title='Subjectivity')
plt.show()

# %%
import statistics
statistics.mean(poltweet.polarity)
# Out:
# 0.04769487423495813

# %%
import statistics
statistics.mean(poltweet.subjectivity)
# Out:
# 0.3382478373237421

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

def wc(data,bgcolor,title):
    plt.figure(figsize = (100,100))
    wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
top_N = 100


a = dataset1['text'].str.lower().str.cat(sep=' ')


b = re.sub('[^A-Za-z]+', ' ', a)
nltk.download('stopwords')
nltk.download('punkt')
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import seaborn as sns
 
without_single_chr = [word for word in filtered_sentence if len(word) > 2]


cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        


word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Common Words' )

# %%
from textblob import TextBlob

bloblist_desc = list()

twit=dataset1['text'].astype(str)
for row in twit:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    twit_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
    
def f(twit_polarity_desc):
    if twit_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif twit_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

twit_polarity_desc['Sentiment_Type'] = twit_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.countplot(x="Sentiment_Type", data=twit_polarity_desc)

# %%
import collections, numpy as np
a=twit_polarity_desc.Sentiment_Type
neut=np.count_nonzero(a == 'Neutral')
pos=np.count_nonzero(a == 'Positive')
neg=np.count_nonzero(a == 'Negative')
popularity='{0:.2f}'.format((((neut*0.5)+(pos)+(neg*0))/(neut+pos+neg))*100)
popularity
# Out:
# '51.32'
