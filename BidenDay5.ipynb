# %%
import sys

# %%
import numpy as np
import pandas as pd
import tweepy
import matplotlib.pyplot as plt
import pymongo
import ipywidgets as wgt
from IPython.display import display
from sklearn.feature_extraction.text import CountVectorizer
import re
from datetime import datetime

# %matplotlib inline

# %%
api_key = "pCRLPdf2lkjpRX9Uczpt2gVBb" 
api_secret = "G1Wv7sTLMYF3cr5LbL8S9uj2g2LFrdWp8X8t7Ft3sIpW0kbqgD" 
access_token = "100875722-7m5vhOzpw2LYrB7P8ISnTqtGYMMvVTqwx3X4EyJY" 
access_token_secret = "uPEymGiszhiJEVWD4Alo1pzMUJx1ymo3Fd4HWyRPRBN3r" 

auth = tweepy.OAuthHandler(api_key, api_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)
col = pymongo.MongoClient()["DataWranglingDay3"]["Biden"]
col.count()
# Out:
# <ipython-input-177-900ad86d5f6d>:11: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   col.count()
# 15000

# %%
class MyStreamListener(tweepy.StreamListener):
    
    counter = 0
    
    def __init__(self, max_tweets=3000, *args, **kwargs):
        self.max_tweets = max_tweets
        self.counter = 0
        super().__init__(*args, **kwargs)
    
    def on_connect(self):
        self.counter = 0
        self.start_time = datetime.now()
    
    def on_status(self, status):
        
        self.counter += 1
        
        
        col.insert_one(status._json)
        
        
        if self.counter % 1 == 0:
            value = int(100.00 * self.counter / self.max_tweets)
            mining_time = datetime.now() - self.start_time
            progress_bar.value = value
            html_value = """<span class="label label-primary">Tweets/Sec: %.1f</span>""" % (self.counter / max([1,mining_time.seconds]))
            html_value += """ <span class="label label-success">Progress: %.1f%%</span>""" % (self.counter / self.max_tweets * 100.0)
            html_value += """ <span class="label label-info">ETA: %.1f Sec</span>""" % ((self.max_tweets - self.counter) / (self.counter / max([1,mining_time.seconds])))
            wgt_status.value = html_value
           
            if self.counter >= self.max_tweets:
                myStream.disconnect()
                print("Finished")
                print("Total Mining Time: %s" % (mining_time))
                print("Tweets/Sec: %.1f" % (self.max_tweets / mining_time.seconds))
                progress_bar.value = 0
                
    
myStreamListener = MyStreamListener(max_tweets=5000)
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
keywords = ["Biden",""
           ]


progress_bar = wgt.IntProgress(value=0)
display(progress_bar)
wgt_status = wgt.HTML(value="""<span class="label label-primary">Tweets/Sec: 0.0</span>""")
display(wgt_status)


for error_counter in range(20):
    try:
        myStream.filter(track=keywords)
        print("Tweets collected: %s" % myStream.listener.counter)
        print("Total tweets in collection: %s" % col.count())
        break
    except:
        print("ERROR# %s" % (error_counter + 1))
# Out:
# IntProgress(value=0)
# HTML(value='<span class="label label-primary">Tweets/Sec: 0.0</span>')
# Tweets collected: 0
# Total tweets in collection: 15000
# <ipython-input-178-2b9117ab4939>:55: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   print("Total tweets in collection: %s" % col.count())

# %%
col.find_one()
# Out:
# {'_id': ObjectId('5f9d1d664513326e3a537dc6'),
#  'created_at': 'Sat Oct 31 08:16:32 +0000 2020',
#  'id': 1322452381481738241,
#  'id_str': '1322452381481738241',
#  'text': 'NBC News debunks old Hunter Biden non-story to distract from real story of influence peddling… https://t.co/b4k8HOvzjS',
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'truncated': True,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 1238615849872904205,
#   'id_str': '1238615849872904205',
#   'name': 'Lui Kitayama',
#   'screen_name': 'KitayamaLui',
#   'location': None,
#   'url': None,
#   'description': 'Retired LEO. Independent conservative. Pro President Trump. 🇺🇸🇺🇸🇺🇸',
#   'translator_type': 'none',
#   'protected': False,
#   'verified': False,
#   'followers_count': 1808,
#   'friends_count': 3050,
#   'listed_count': 0,
#   'favourites_count': 37811,
#   'statuses_count': 43866,
#   'created_at': 'Sat Mar 14 00:00:27 +0000 2020',
#   'utc_offset': None,
#   'time_zone': None,
#   'geo_enabled': True,
#   'lang': None,
#   'contributors_enabled': False,
#   'is_translator': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1238616156946169862/cwBhfihF_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1238616156946169862/cwBhfihF_normal.jpg',
#   'default_profile': True,
#   'default_profile_image': False,
#   'following': None,
#   'follow_request_sent': None,
#   'notifications': None},
#  'geo': None,
#  'coordinates': None,
#  'place': None,
#  'contributors': None,
#  'is_quote_status': False,
#  'extended_tweet': {'full_text': 'NBC News debunks old Hunter Biden non-story to distract from real story of influence peddling https://t.co/E4gPzIkUsE \n\nNBC is the enemy of the American people.',
#   'display_text_range': [0, 160],
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/E4gPzIkUsE',
#      'expanded_url': 'https://legalinsurrection.com/2020/10/nbc-news-debunks-old-hunter-biden-non-story-to-distract-from-real-story-of-influence-peddling/',
#      'display_url': 'legalinsurrection.com/2020/10/nbc-ne…',
#      'indices': [94, 117]}],
#    'user_mentions': [],
#    'symbols': []}},
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'favorite_count': 0,
#  'entities': {'hashtags': [],
#   'urls': [{'url': 'https://t.co/b4k8HOvzjS',
#     'expanded_url': 'https://twitter.com/i/web/status/1322452381481738241',
#     'display_url': 'twitter.com/i/web/status/1…',
#     'indices': [95, 118]}],
#   'user_mentions': [],
#   'symbols': []},
#  'favorited': False,
#  'retweeted': False,
#  'possibly_sensitive': False,
#  'filter_level': 'low',
#  'lang': 'en',
#  'timestamp_ms': '1604132192379'}

# %%
dataset = [{"created_at": item["created_at"],
            "text": item["text"],
            "user": "@%s" % item["user"]["screen_name"],
            "source": item["source"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset = pd.DataFrame(dataset)

dataset
# Out:
#                            created_at  \
# 0      Sat Oct 31 08:16:32 +0000 2020
# 1      Sat Oct 31 08:16:32 +0000 2020
# 2      Sat Oct 31 08:16:32 +0000 2020
# 3      Sat Oct 31 08:16:32 +0000 2020
# 4      Sat Oct 31 08:16:32 +0000 2020
# ...                               ...
# 14995  Sat Oct 31 08:38:42 +0000 2020
# 14996  Sat Oct 31 08:38:42 +0000 2020
# 14997  Sat Oct 31 08:38:42 +0000 2020
# 14998  Sat Oct 31 08:38:43 +0000 2020
# 14999  Sat Oct 31 08:38:43 +0000 2020
#
#                                                     text             user  \
# 0      NBC News debunks old Hunter Biden non-story to...     @KitayamaLui
# 1      RT @RealJamesWoods: And name a SINGLE achievem...      @Exx_______
# 2      The " Land of the Free " has a very hollow rin...     @caronastley
# 3      RT @F_Desouche: États-Unis : Facebook et Twitt...  @Meruem1erDuNom
# 4      RT @feelthemana: Under the Biden plan , Hawaii...   @Donna15935308
# ...                                                  ...              ...
# 14995  RT @AbuRaziel: @AsteadWesley All Biden needs t...   @fresh_fer_sho
# 14996  RT @NpdAnalysis: America needs Jeb and George ...    @Twelve217114
# 14997  RT @RealJamesWoods: So Jack Dorsey FINALLY dei...    @ClickOffAnon
# 14998  RT @DanScavino: “Trump: Biden ‘Twisted the Kni...    @ladyhawk0568
# 14999  @JinniHTX @RashidaTlaib Joe Biden is a plagiar...       @Woodrow17
#
#                                                   source lang
# 0      <a href="https://mobile.twitter.com" rel="nofo...   en
# 1      <a href="http://twitter.com/download/android" ...   en
# 2      <a href="http://twitter.com/download/android" ...   en
# 3      <a href="http://twitter.com/download/android" ...   fr
# 4      <a href="http://twitter.com/download/iphone" r...   en
# ...                                                  ...  ...
# 14995  <a href="http://twitter.com/download/iphone" r...   en
# 14996  <a href="http://twitter.com/download/android" ...   en
# 14997  <a href="http://twitter.com/download/android" ...   en
# 14998  <a href="http://twitter.com/download/iphone" r...   en
# 14999  <a href="https://mobile.twitter.com" rel="nofo...   en
#
# [15000 rows x 5 columns]

# %%
cv = CountVectorizer()
count_matrix = cv.fit_transform(dataset.text)

word_count = pd.DataFrame(cv.get_feature_names(), columns=["word"])
word_count["count"] = count_matrix.sum(axis=0).tolist()[0]
word_count = word_count.sort_values("count", ascending=False).reset_index(drop=True)
word_count[:50]
# Out:
#                word  count
# 0                rt  11270
# 1             biden  10508
# 2               the   8190
# 3                to   6056
# 4               and   4469
# 5             https   4464
# 6                co   4397
# 7                in   3846
# 8                is   3732
# 9                of   3577
# 10              joe   3549
# 11              for   2605
# 12             that   2405
# 13  realdonaldtrump   2211
# 14            trump   2187
# 15              you   1955
# 16              are   1660
# 17               it   1595
# 18           hunter   1556
# 19             this   1495
# 20               he   1406
# 21              has   1387
# 22               be   1359
# 23               on   1311
# 24              his   1193
# 25             will   1142
# 26               if   1070
# 27            would   1063
# 28             vote    991
# 29             with    935
# 30             they    921
# 31              our    892
# 32            about    869
# 33        president    863
# 34              not    856
# 35               as    840
# 36             have    819
# 37               up    801
# 38               we    800
# 39              who    715
# 40               an    699
# 41              out    660
# 42             from    660
# 43   realjameswoods    655
# 44              but    638
# 45               no    638
# 46              was    628
# 47              all    616
# 48         campaign    611
# 49          because    606

# %%
def get_source_name(x):
    value = re.findall(pattern="<[^>]+>([^<]+)</a>", string=x)
    if len(value) > 0:
        return value[0]
    else:
        return ""
dataset.source_name = dataset.source.apply(get_source_name)

source_counts = dataset.source_name.value_counts().sort_values()[-10:]

bottom = [index for index, item in enumerate(source_counts.index)]
plt.barh(bottom, width=source_counts, color="blue", linewidth=0)

y_labels = ["%s %.1f%%" % (item, 100.0*source_counts[item]/len(dataset)) for index,item in enumerate(source_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)

source_counts
# Out:
# <ipython-input-182-a8481ec67a37>:7: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   dataset.source_name = dataset.source.apply(get_source_name)
# Twitterrific for iOS      10
# IFTTT                     14
# Tweetbot for iΟS          17
# dlvr.it                   19
# WordPress.com             32
# TweetDeck                 33
# Twitter for iPad         918
# Twitter Web App         3715
# Twitter for Android     4871
# Twitter for iPhone      5244
# Name: source, dtype: int64

# %%
lang_counts = dataset.lang.value_counts().sort_values()[-10:]
bottom = [index for index, item in enumerate(lang_counts.index)]
plt.barh(bottom, width=lang_counts, color="green", linewidth=0)
y_labels = ["%s %.1f%%" % (item, 100.0*lang_counts[item]/len(dataset)) for index,item in enumerate(lang_counts.index)]
plt.yticks(np.array(bottom)+0.4, y_labels)
lang_counts
# Out:
# it        41
# pt        43
# zh        49
# nl        60
# ja        82
# de       105
# fr       210
# es       295
# und      638
# en     13255
# Name: lang, dtype: int64

# %%
from pandas.io.json import json_normalize
import matplotlib.pyplot as plt
from  textblob import TextBlob

# %%
dataset1 = [{"id": item["id"],
            "text": item["text"],
            "lang":item["lang"],
            
           } for item in col.find()]

dataset1 = pd.DataFrame(dataset1)

is_dataset1=dataset1.lang=="en"
dataset1=dataset1[is_dataset1]
dataset1
# Out:
#                         id                                               text  \
# 0      1322452381481738241  NBC News debunks old Hunter Biden non-story to...
# 1      1322452381930586117  RT @RealJamesWoods: And name a SINGLE achievem...
# 2      1322452382068953089  The " Land of the Free " has a very hollow rin...
# 4      1322452382693949440  RT @feelthemana: Under the Biden plan , Hawaii...
# 5      1322452383289532416  Joe Biden Lies All The Time, But The Media Jus...
# ...                    ...                                                ...
# 14995  1322457962099728384  RT @AbuRaziel: @AsteadWesley All Biden needs t...
# 14996  1322457962175209473  RT @NpdAnalysis: America needs Jeb and George ...
# 14997  1322457962426830848  RT @RealJamesWoods: So Jack Dorsey FINALLY dei...
# 14998  1322457962716319744  RT @DanScavino: “Trump: Biden ‘Twisted the Kni...
# 14999  1322457962812645376  @JinniHTX @RashidaTlaib Joe Biden is a plagiar...
#
#       lang
# 0       en
# 1       en
# 2       en
# 4       en
# 5       en
# ...    ...
# 14995   en
# 14996   en
# 14997   en
# 14998   en
# 14999   en
#
# [13255 rows x 3 columns]

# %%
tweettext=dataset1['text']
wordlist=pd.DataFrame();

polarity=[]
subj=[]

for t in tweettext:
    tx= TextBlob(t)
    polarity.append(tx.sentiment.polarity)
    subj.append(tx.sentiment.subjectivity)

poltweet= pd.DataFrame({'polarity':polarity,'subjectivity':subj})
poltweet.polarity.plot(title='Polarity')
plt.show()

# %%
poltweet.subjectivity.plot(title='Subjectivity')
plt.show()

# %%
import statistics
statistics.mean(poltweet.polarity)
# Out:
# 0.04445275900030371

# %%
import statistics
statistics.mean(poltweet.subjectivity)
# Out:
# 0.34640285337418497

# %%
from wordcloud import WordCloud
import nltk
from nltk.corpus import stopwords
from nltk import sent_tokenize, word_tokenize
from wordcloud import WordCloud, STOPWORDS

def wc(data,bgcolor,title):
    plt.figure(figsize = (100,100))
    wc = WordCloud(background_color = bgcolor, max_words = 1000,  max_font_size = 50)
    wc.generate(' '.join(data))
    plt.imshow(wc)
    plt.axis('off')

# %%
from collections import Counter
from nltk.tokenize import RegexpTokenizer
from stop_words import get_stop_words
import re
top_N = 100


a = dataset1['text'].str.lower().str.cat(sep=' ')


b = re.sub('[^A-Za-z]+', ' ', a)
nltk.download('stopwords')
nltk.download('punkt')
stop_words = list(get_stop_words('en'))         
nltk_words = list(stopwords.words('english'))   
stop_words.extend(nltk_words)
word_tokens = word_tokenize(b)
filtered_sentence = [w for w in word_tokens if not w in stop_words]
filtered_sentence = []
for w in word_tokens:
    if w not in stop_words:
        filtered_sentence.append(w)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import seaborn as sns
 
without_single_chr = [word for word in filtered_sentence if len(word) > 2]


cleaned_data_title = [word for word in without_single_chr if not word.isnumeric()]        


word_dist = nltk.FreqDist(cleaned_data_title)
rslt = pd.DataFrame(word_dist.most_common(top_N),
                    columns=['Word', 'Frequency'])

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.barplot(x="Word",y="Frequency", data=rslt.head(7))

# %%
wc(cleaned_data_title,'black','Common Words' )

# %%
from textblob import TextBlob

bloblist_desc = list()

twit=dataset1['text'].astype(str)
for row in twit:
    blob = TextBlob(row)
    bloblist_desc.append((row,blob.sentiment.polarity, blob.sentiment.subjectivity))
    twit_polarity_desc = pd.DataFrame(bloblist_desc, columns = ['sentence','sentiment','polarity'])
    
def f(twit_polarity_desc):
    if twit_polarity_desc['sentiment'] > 0:
        val = "Positive"
    elif twit_polarity_desc['sentiment'] == 0:
        val = "Neutral"
    else:
        val = "Negative"
    return val

twit_polarity_desc['Sentiment_Type'] = twit_polarity_desc.apply(f, axis=1)

plt.figure(figsize=(10,10))
sns.set_style("whitegrid")
ax = sns.countplot(x="Sentiment_Type", data=twit_polarity_desc)

# %%
import collections, numpy as np
a=twit_polarity_desc.Sentiment_Type
neut=np.count_nonzero(a == 'Neutral')
pos=np.count_nonzero(a == 'Positive')
neg=np.count_nonzero(a == 'Negative')
popularity='{0:.2f}'.format((((neut*0.5)+(pos)+(neg*0))/(neut+pos+neg))*100)
popularity
# Out:
# '57.97'
